# %%
#This notebook is to answer Question #3
# What features influence the price. Predict the price using ML model.

# In this notebook, we will create a Linear Regression Model to predict the features that influence the price. 
# We want to know what features are directly related to the price. 
# We will also perform data cleaning and data wrangling operations before the data can be fed into the model for prediction.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error

listing = pd.read_csv('listings.csv') #reading the listing dataset in a datafram called 'listing'
listing.head() #displaying the enteries of the dataframe 'listing'
# Out:
#              id                                               name    host_id  \
# 0          1944                             cafeheaven Pberg/Mitte       2164
# 1          3176                    Fabulous Flat in great Location       3718
# 2          3309                  BerlinSpot Schöneberg near KaDeWe       4108
# 3          6883  Stylish East Side Loft in Center with AC & 2 b...      16149
# 4          7071                   BrightRoom with sunny greenview!      17391
# 5          9991                Geourgeous flat - outstanding views      33852
# 6         14325                       Apartment in Prenzlauer Berg      55531
# 7         16644                 In the Heart of Berlin - Kreuzberg      64696
# 8         17904       Beautiful Kreuzberg studio/WiFi (reg. pend.)      68997
# 9         20858                      Designer Loft in Berlin Mitte      71331
# 10        21869                   Studio in the Heart of Kreuzberg      64696
# 11        22415                    Stylishly furnished 3 room flat      86068
# 12        22677   Prenzel garden with leafy terrace (quiet Guests)      87357
# 13        23834                   Apartment in the heart of Berlin      94918
# 14        24569                      Sunny & Wheelchair accessible      99662
# 15        25653                  Sunny & stylish 150 sqm apartment      99662
# 16        26543                Helmholtzplatz Bright&Spacious Apt.     112675
# 17        28156             Beautiful apartment in Prenzlauer Berg      55531
# 18        29279                  Quiet 2 rooms next Helmholtzplatz      54283
# 19        30295  PEACEFUL FLAT WITH VINTAGE TOUCH IN PRENZLAUER...     485838
# 20        33043       Central Bright Bellevue Free Parking WIFI 4G     143180
# 21        35152      Private Room w/ own bath in Design Mitte Loft     151248
# 22        36480                   ChimaysaberlinB&B Single Bedroom     156897
# 23        37004     WONDERFUL ROOM for longer stays Berlin Central     159734
# 24        37836                Weekend in Berlin Party Center - II     272316
# 25        38074  3 months min stay in the heart of Prenzlauer B...     163384
# 26        38296   nice apartment to rent in Neukölln in September!     164310
# 27        40600                 room-artist loft berlin kreuzberg      174970
# 28        41217                  Beautiful room in Prenzlauer Berg     179110
# 29        41306           Schöner Altbau, 6 min zum Alexanderpatz.     179872
# ...         ...                                                ...        ...
# 24556  40030018       Green Room in shared apartment in Neukölln ♡   66352019
# 24557  40031078                                    Potsdamer Platz  259940521
# 24558  40031527                 Ruhige Wohnung im grünen Tempelhof  227122628
# 24559  40032656               Schöne helle Wohnung in ruhiger Lage  308751316
# 24560  40033041       Big cosy room in the heart of Friedrichshain   20391171
# 24561  40033117     Charming and spacious Berlin alt-bau apartment   47085194
# 24562  40033253      135m2 Dachgeschosswohnung mitten in Kreuzberg  152433331
# 24563  40033543                           Im Herzen von Kreuzberg!  303907775
# 24564  40033719                                   Apartment Berlin  299821211
# 24565  40034864         Beautiful apartment in the heart of Berlin  100998849
# 24566  40036292                   Nice shared Flat with balcony :)  216384404
# 24567  40041132             Cozy Room in Apartment on Mitte,Berlin  308567114
# 24568  40043888                  Berlin in traumhaft ruhiger Lage.  308855555
# 24569  40045415            Light beautiful room in Berlin-Neukölln   30270044
# 24570  40046638          WG-Zimmer Friedrichshain-Samariterstrasse  308872778
# 24571  40047884                 Spacious flat in central Kreuzberg   58019005
# 24572  40048272                   Top Zimmer, Top Preis, Top Lage!  308885379
# 24573  40048511  2-Zi.-Wohnung in Parknähe mit grossem Familien...   98355091
# 24574  40050071                   Zentrale helle Wohnung in Berlin   42476536
# 24575  40050349     Sunny room in Berlin near the Center of Berlin   24225592
# 24576  40050350      Bright & spacious Altbau apartment on Ku‘damm   61951273
# 24577  40050449                     new 1-room apartment in berlin  171388808
# 24578  40052646                 Zum zum zum Glück nicht so viel zu  308914119
# 24579  40054722  Spacious 2 Bedroom Luxury Loft in Berlin Kreuz...     401446
# 24580  40055757                           Secret Pearl Of Neukölln   61290674
# 24581  40055760                        Das ist eine gute Idee aber  308937636
# 24582  40057919                 Spacious apartment in Bergmannkiez    2825203
# 24583  40061108                   A lovely room in Prenzlauer Berg   33523795
# 24584  40070345                   Chilled room in shared apartment  151694237
# 24585  40086295               "No-fuss" central Neukölln apartment    7793059
#
#             host_name       neighbourhood_group             neighbourhood  \
# 0               Lulah                     Mitte          Brunnenstr. Nord
# 1              Britta                    Pankow   Prenzlauer Berg Südwest
# 2                Jana    Tempelhof - Schöneberg           Schöneberg-Nord
# 3             Steffen  Friedrichshain-Kreuzberg  Frankfurter Allee Süd FK
# 4          BrightRoom                    Pankow            Helmholtzplatz
# 5             Philipp                    Pankow   Prenzlauer Berg Südwest
# 6      Chris + Oliver                    Pankow  Prenzlauer Berg Nordwest
# 7                Rene  Friedrichshain-Kreuzberg     nördliche Luisenstadt
# 8            Matthias                  Neukölln              Reuterstraße
# 9                Marc                    Pankow   Prenzlauer Berg Südwest
# 10               Rene  Friedrichshain-Kreuzberg     nördliche Luisenstadt
# 11               Kiki  Friedrichshain-Kreuzberg      südliche Luisenstadt
# 12             Ramfis                     Mitte           Brunnenstr. Süd
# 13              Tanja  Friedrichshain-Kreuzberg      Tempelhofer Vorstadt
# 14            Dominik                    Pankow   Prenzlauer Berg Südwest
# 15            Dominik                    Pankow       Prenzlauer Berg Süd
# 16              Terri                    Pankow            Helmholtzplatz
# 17     Chris + Oliver                    Pankow  Prenzlauer Berg Nordwest
# 18             Marine                    Pankow            Helmholtzplatz
# 19            Michele                    Pankow            Helmholtzplatz
# 20      Claudio&Irina                     Mitte                Moabit Ost
# 21                Flo                     Mitte           Brunnenstr. Süd
# 22              Helen      Charlottenburg-Wilm.           Otto-Suhr-Allee
# 23              Bernd    Tempelhof - Schöneberg           Schöneberg-Nord
# 24            Desiree  Friedrichshain-Kreuzberg      südliche Luisenstadt
# 25       Alan & Kasia                    Pankow       Prenzlauer Berg Süd
# 26             Oliver                  Neukölln         Schillerpromenade
# 27             Judith  Friedrichshain-Kreuzberg      Tempelhofer Vorstadt
# 28                 Bn                    Pankow   Prenzlauer Berg Südwest
# 29          Sebastian                    Pankow       Prenzlauer Berg Süd
# ...               ...                       ...                       ...
# 24556          Liubov                  Neukölln                   Rixdorf
# 24557           Kefah                     Mitte            Tiergarten Süd
# 24558        Hassanin    Tempelhof - Schöneberg                 Tempelhof
# 24559            Sara     Steglitz - Zehlendorf                 Drakestr.
# 24560          Florin  Friedrichshain-Kreuzberg       Karl-Marx-Allee-Süd
# 24561         Matthew                    Pankow                 Weißensee
# 24562       Margarita  Friedrichshain-Kreuzberg      Tempelhofer Vorstadt
# 24563      Jacqueline  Friedrichshain-Kreuzberg      südliche Luisenstadt
# 24564         Leonard                  Neukölln                    Buckow
# 24565      Anne-Sofie                     Mitte            Alexanderplatz
# 24566         Philipp                     Mitte           Wedding Zentrum
# 24567          Marian                     Mitte            Tiergarten Süd
# 24568          Sheila                    Pankow                     Karow
# 24569         Marieke                  Neukölln                   Rixdorf
# 24570           Nadir  Friedrichshain-Kreuzberg    Frankfurter Allee Nord
# 24571        Henrieke  Friedrichshain-Kreuzberg   Südliche Friedrichstadt
# 24572               B  Friedrichshain-Kreuzberg      südliche Luisenstadt
# 24573             Uta                     Mitte               Parkviertel
# 24574          Gesine                     Mitte               Moabit West
# 24575         Leticia               Lichtenberg           Neu Lichtenberg
# 24576          Gedeon      Charlottenburg-Wilm.            Kurfürstendamm
# 24577              보희     Steglitz - Zehlendorf                 Drakestr.
# 24578            Dcvv      Charlottenburg-Wilm.       Düsseldorfer Straße
# 24579         Florian  Friedrichshain-Kreuzberg      südliche Luisenstadt
# 24580           Julia                  Neukölln  Neuköllner Mitte/Zentrum
# 24581            Gcvb                     Mitte            Alexanderplatz
# 24582       Christoph  Friedrichshain-Kreuzberg      Tempelhofer Vorstadt
# 24583           Einat                    Pankow            Helmholtzplatz
# 24584           Sagir                  Neukölln  Neuköllner Mitte/Zentrum
# 24585           James                  Neukölln  Neuköllner Mitte/Zentrum
#
#        latitude  longitude        room_type  price  minimum_nights  \
# 0      52.54425   13.39749     Private room     21              60
# 1      52.53500   13.41758  Entire home/apt     90              62
# 2      52.49885   13.34906     Private room     28               7
# 3      52.51171   13.45477  Entire home/apt    125               3
# 4      52.54316   13.41509     Private room     33               3
# 5      52.53303   13.41605  Entire home/apt    180               6
# 6      52.54785   13.40556  Entire home/apt     70              90
# 7      52.50479   13.43510  Entire home/apt     90              60
# 8      52.49548   13.42182  Entire home/apt     49               5
# 9      52.53695   13.40762  Entire home/apt    129               3
# 10     52.50273   13.43462  Entire home/apt     70              60
# 11     52.49485   13.42850  Entire home/apt     98               2
# 12     52.53435   13.40558  Entire home/apt    160               2
# 13     52.48971   13.37975  Entire home/apt     65              60
# 14     52.53079   13.41808  Entire home/apt     90               3
# 15     52.53026   13.41947  Entire home/apt     90               4
# 16     52.54406   13.42138  Entire home/apt    209               3
# 17     52.54672   13.40512  Entire home/apt     70              90
# 18     52.54179   13.42388  Entire home/apt     65              60
# 19     52.54597   13.42236  Entire home/apt    100               4
# 20     52.52142   13.35708  Entire home/apt     62               2
# 21     52.53506   13.39699     Private room     75               2
# 22     52.51968   13.30209     Private room     40               1
# 23     52.49339   13.36481     Private room     30              10
# 24     52.49847   13.44013     Private room     39               3
# 25     52.53680   13.42547  Entire home/apt     80              84
# 26     52.48586   13.42362  Entire home/apt     80              10
# 27     52.48844   13.42060     Private room     50               3
# 28     52.53641   13.41231     Private room     43               2
# 29     52.53028   13.42348     Private room     40               1
# ...         ...        ...              ...    ...             ...
# 24556  52.47808   13.44662     Private room     65               2
# 24557  52.50476   13.37346  Entire home/apt    149             180
# 24558  52.46769   13.38879  Entire home/apt     89               2
# 24559  52.42025   13.28058  Entire home/apt     66               1
# 24560  52.51347   13.44622     Private room     30               3
# 24561  52.55581   13.43057  Entire home/apt    100              30
# 24562  52.49687   13.38511  Entire home/apt    200               5
# 24563  52.49860   13.44309  Entire home/apt     60               1
# 24564  52.42099   13.44440  Entire home/apt     39               3
# 24565  52.52527   13.40964  Entire home/apt    600               1
# 24566  52.55554   13.36930     Private room     35               2
# 24567  52.50572   13.35274     Private room     18              30
# 24568  52.60889   13.45758  Entire home/apt     70               1
# 24569  52.48233   13.44502     Private room     22               2
# 24570  52.51918   13.46678     Private room     50               1
# 24571  52.49575   13.41452  Entire home/apt    121               1
# 24572  52.49989   13.43697     Private room     34               2
# 24573  52.55384   13.34061  Entire home/apt     70               6
# 24574  52.52861   13.33809     Private room     30               1
# 24575  52.50160   13.49418     Private room     39               4
# 24576  52.50192   13.32933  Entire home/apt    250               1
# 24577  52.44431   13.31974  Entire home/apt     50               1
# 24578  52.49809   13.31016  Entire home/apt     77               1
# 24579  52.49480   13.43813  Entire home/apt    165              30
# 24580  52.47534   13.43895     Private room     29               2
# 24581  52.53395   13.37909  Entire home/apt     77               1
# 24582  52.49171   13.39808  Entire home/apt    140               1
# 24583  52.54515   13.42161     Private room     20               2
# 24584  52.47714   13.43017     Private room     35               4
# 24585  52.48091   13.43066     Private room     35               5
#
#        number_of_reviews last_review  reviews_per_month  \
# 0                     18  2018-11-11               0.24
# 1                    145  2019-06-27               1.14
# 2                     27  2019-05-31               0.35
# 3                    128  2019-10-21               1.08
# 4                    266  2019-11-09               2.13
# 5                      7  2019-07-15               0.13
# 6                     24  2019-07-01               0.21
# 7                     48  2017-12-14               0.42
# 8                    252  2019-11-11               2.13
# 9                     81  2019-11-04               0.93
# 10                    60  2016-06-05               0.54
# 11                    77  2019-10-06               0.67
# 12                   286  2019-11-04               2.58
# 13                   130  2019-10-02               1.13
# 14                    20  2019-11-08               0.18
# 15                     5  2016-08-14               0.04
# 16                   185  2019-11-02               1.64
# 17                    30  2019-04-15               0.27
# 18                    73  2019-07-31               0.66
# 19                   286  2019-11-10               2.56
# 20                   192  2019-11-04               1.71
# 21                    17  2019-11-11               0.17
# 22                    48  2019-11-02               1.47
# 23                    24  2019-07-03               0.21
# 24                   189  2019-10-25               1.66
# 25                   105  2019-10-28               0.94
# 26                     6  2012-07-27               0.05
# 27                    50  2016-09-26               0.54
# 28                    70  2017-10-08               0.62
# 29                     1  2014-09-26               0.02
# ...                  ...         ...                ...
# 24556                  0         NaN                NaN
# 24557                  0         NaN                NaN
# 24558                  0         NaN                NaN
# 24559                  0         NaN                NaN
# 24560                  0         NaN                NaN
# 24561                  0         NaN                NaN
# 24562                  0         NaN                NaN
# 24563                  0         NaN                NaN
# 24564                  0         NaN                NaN
# 24565                  0         NaN                NaN
# 24566                  0         NaN                NaN
# 24567                  0         NaN                NaN
# 24568                  0         NaN                NaN
# 24569                  0         NaN                NaN
# 24570                  0         NaN                NaN
# 24571                  0         NaN                NaN
# 24572                  0         NaN                NaN
# 24573                  0         NaN                NaN
# 24574                  0         NaN                NaN
# 24575                  0         NaN                NaN
# 24576                  0         NaN                NaN
# 24577                  0         NaN                NaN
# 24578                  0         NaN                NaN
# 24579                  0         NaN                NaN
# 24580                  0         NaN                NaN
# 24581                  0         NaN                NaN
# 24582                  0         NaN                NaN
# 24583                  0         NaN                NaN
# 24584                  0         NaN                NaN
# 24585                  0         NaN                NaN
#
#        calculated_host_listings_count  availability_365
# 0                                   1               251
# 1                                   1               344
# 2                                   1               317
# 3                                   1                20
# 4                                   2                30
# 5                                   1                45
# 6                                   4               215
# 7                                   2                87
# 8                                   1               286
# 9                                   1               167
# 10                                  2               165
# 11                                  2                95
# 12                                  1               280
# 13                                  1                73
# 14                                  2                 3
# 15                                  2                 0
# 16                                  1               347
# 17                                  4               172
# 18                                  3               286
# 19                                  4               264
# 20                                  1                43
# 21                                  1               240
# 22                                  2               321
# 23                                  1               287
# 24                                  2               170
# 25                                 10               168
# 26                                  1               317
# 27                                  2                 0
# 28                                  1                 0
# 29                                  1                 0
# ...                               ...               ...
# 24556                               1                 5
# 24557                               1               360
# 24558                               1                43
# 24559                               1                84
# 24560                               2               324
# 24561                               1                59
# 24562                               1                54
# 24563                               1                 6
# 24564                               1                 6
# 24565                               1                11
# 24566                               1                16
# 24567                               1               229
# 24568                               1               145
# 24569                               1                 7
# 24570                               1                40
# 24571                               1                 0
# 24572                               1                 4
# 24573                               1                38
# 24574                               1                 5
# 24575                               1                 0
# 24576                               1                31
# 24577                               1               152
# 24578                               1                89
# 24579                               6                84
# 24580                               1                 3
# 24581                               1                73
# 24582                               2                 9
# 24583                               1                13
# 24584                               3               303
# 24585                               1                19
#
# [24586 rows x 16 columns]

# %%
def clean_data(df):
    '''
    INPUT
    df - pandas dataframe 
    
    OUTPUT
    X - A matrix holding all of the features you want to consider when predicting the response
    y - the corresponding response vector
    
    Perform to obtain the correct X and y objects
    This function cleans df using the following steps to produce X and y:
    1. Drop all the rows with no price
    2. Create X as all the columns that are not the price column and that are numeric
    3. Create y as the price column
    4. Drop the 'id', 'name', 'host_id', 'host_name','neighbourhood', 'latitude', 'longitude', 'price',
                'last_review','calculated_host_listings_count', 'availability_365' columns from X
    5. For each numeric variable in X, fill the column with the mean value of the column.
    6. Create dummy columns for all the categorical variables in X, drop the original columns
    7. Return X and y
    '''
    
    #Drop all the rows with no price
    df = df.dropna(subset = ['price'], axis = 0)
    y = df['price']
    
    #Drop columns that we do not want to consider 
    df = df.drop(['id', 'name', 'host_id', 'host_name',
                  'neighbourhood', 'latitude', 'longitude', 'price',
                  'last_review'], axis = 1)
    
    
    #Fill the mean in the columns where we have some NaN values.
    num_vars = df.select_dtypes(include = ['float', 'int']).columns
    for col in num_vars:
        df[col].fillna((df[col].mean()), inplace = True)
        
        
    #Fill Dummy variables for the categorical columns. 
    cat_vars = df.select_dtypes(include = ['object']).copy().columns
    for var in cat_vars:
        df = pd.concat([df.drop(var, axis = 1), pd.get_dummies(df[var], prefix =var, prefix_sep='_', drop_first=False)], axis = 1)
        
    X = df
    return X, y
    
#Use the function to create X and y
X, y = clean_data(listing)

# %%
#Create Training and Testing data

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
#Instantiat the Model
lm_model = LinearRegression(normalize=False)

# %%
#Fit the Model

lm_model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
#Predictions
y_test_preds = lm_model.predict(X_test)
y_train_preds = lm_model.predict(X_train)

# %%
#Scoring the Model

test_score = r2_score(y_test, y_test_preds)
train_score = r2_score(y_train, y_train_preds)

# %%
#Print training and testing score
print("The rsquared on the training data was {}.  The rsquared on the test data was {}.".format(train_score, test_score))
# Out:
# The rsquared on the training data was 0.13998550844860203.  The rsquared on the test data was 0.12438280041842009.

# %%
# From the above results of 'rsquared' values, we can see that our model is not predicting the outcomes in the most appropriate way.
# rsquared of almost 13% on both Training and Test datasets shows the limitations of our model. One of the main reasons for this
# is that I have used very few features to predict the price. If i Had used more features, i could have achieved better results. 
# The data set i used for my project is the summarized version and contains only few columns. During data cleaning, i dropped 
# certain columns that were not useful.

# %%
def coef_weights(coefficients, X_train):
    '''
    INPUT:
    coefficients - the coefficients of the linear model 
    X_train - the training data, so the column names can be used
    OUTPUT:
    coefs_df - a dataframe holding the coefficient, estimate, and abs(estimate)
    
    Provides a dataframe that can be used to understand the most influential coefficients
    in a linear model by providing the coefficient estimates along with the name of the 
    variable attached to the coefficient.
    '''
    coefs_df = pd.DataFrame()
    coefs_df['est_int'] = X_train.columns
    coefs_df['coefs'] = lm_model.coef_
    coefs_df['abs_coefs'] = np.abs(lm_model.coef_)
    coefs_df = coefs_df.sort_values('abs_coefs', ascending=False)
    return coefs_df

#Use the function
coef_df = coef_weights(lm_model.coef_, X_train)

#A quick look at the results
coef_df
# Out:
#                                          est_int       coefs   abs_coefs
# 18                          room_type_Hotel room  542.686719  542.686719
# 20                         room_type_Shared room -204.264646  204.264646
# 19                        room_type_Private room -189.502010  189.502010
# 17                     room_type_Entire home/apt -148.920062  148.920062
# 13                   neighbourhood_group_Spandau  -43.479768   43.479768
# 15    neighbourhood_group_Tempelhof - Schöneberg   32.421358   32.421358
# 5       neighbourhood_group_Charlottenburg-Wilm.   30.508820   30.508820
# 8      neighbourhood_group_Marzahn - Hellersdorf  -16.139100   16.139100
# 7                neighbourhood_group_Lichtenberg  -12.915212   12.915212
# 9                      neighbourhood_group_Mitte   12.097601   12.097601
# 12             neighbourhood_group_Reinickendorf   -8.897598    8.897598
# 11                    neighbourhood_group_Pankow    5.635942    5.635942
# 6   neighbourhood_group_Friedrichshain-Kreuzberg    3.840946    3.840946
# 14     neighbourhood_group_Steglitz - Zehlendorf   -1.561552    1.561552
# 16        neighbourhood_group_Treptow - Köpenick   -1.199834    1.199834
# 2                              reviews_per_month   -0.885975    0.885975
# 10                  neighbourhood_group_Neukölln   -0.311602    0.311602
# 3                 calculated_host_listings_count    0.166534    0.166534
# 0                                 minimum_nights   -0.116693    0.116693
# 4                               availability_365    0.105213    0.105213
# 1                              number_of_reviews   -0.058940    0.058940

# %%
# From the above results, we can clearly see that the variable/feature 'room_type_Hotelroom' has the highest influence on the price.
# This means that 'room_type' will effect the price heavly either in the positive or negative manner that is, it will predict a higher or lower price.
# depending on the type of the room. If the 'room_type' is Hotel room then our model will predict ahigher price where as if the 'room_type' is shared room, it will predict
# a lessser price. 
# Anopther factor that effects the price, is the 'neighbourhood_group'. Depending on the type of 'neighbourhood_group' price will predicted either higher or lower.
# Neighbourhoods like 'neighbourhood_group_Tempelhof - Schöneberg' will have a positive effect on the prediction of the price and
# Neighbourhood like 'neighbourhood_group_Neukölln' will have a negative effect and our model will predict a lesser price.
# It can also be seen that other features like, 'minimum_nights', 'availability_365' and 'number_of_reviews' have very less effect on the prediction.

# This is the benfit of looking into the coefficients of the model, it tells us which variables/features matter the most in predicting the outcome.
# Obviously, if our model had better rsquared results, the coefficients distribution would have been different but the most important thing
# is to actually understand why the model behaves in a certain way and what factors can be modified to improve the performance of our model
